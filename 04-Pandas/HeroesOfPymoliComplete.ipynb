# %% [markdown]
# ### Heroes Of Pymoli Data Analysis
# * Of the 1163 active players, the vast majority are male (84%). There also exists, a smaller, but notable proportion of female players (14%).
#
# * Our peak age demographic falls between 20-24 (44.8%) with secondary groups falling between 15-19 (18.60%) and 25-29 (13.4%).
# -----

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import pandas as pd

HeroesCSV = "purchase_data.csv"

purchaseData = pd.read_csv(HeroesCSV)
purchaseData.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
cleandata = purchaseData.loc[:, ["Gender", "SN", "Age"]].drop_duplicates()
cleandata.count()
# Out:
# Gender    576
# SN        576
# Age       576
# dtype: int64

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
totalPlayers = purchaseData["Item ID"].value_counts().count()
avgPrice = purchaseData["Price"].mean()
totalItems = purchaseData["Purchase ID"].count()
revenue = purchaseData["Price"].sum()

purchasingSummaryDF = pd.DataFrame()
purchasingSummaryDF["TotalPlayers"] = [totalPlayers]
purchasingSummaryDF["AvgPrice"] = [avgPrice]
purchasingSummaryDF["TotalItems"] = [totalItems]
purchasingSummaryDF["Revenue"] = [revenue]
purchasingSummaryDF
# Out:
#    TotalPlayers  AvgPrice  TotalItems  Revenue
# 0           179  3.050987         780  2379.77

# %% [markdown]
# ## Gender Demographics

# %%
genderDF = cleandata["Gender"].value_counts()
genderDF["% Players"] = cleandata["Gender"].value_counts() / cleandata.count()[0]
genderDF

#Need help here
# Out:
# Male                                                                   484
# Female                                                                  81
# Other / Non-Disclosed                                                   11
# % Players                Male                     0.840278
# Female      ...
# Name: Gender, dtype: object

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gende
#
# * Create a summary data frame to hold the results
#
# * Optional: give the displayed data cleaner formatting
#
# * Display the summary data frame

# %%
genderCount = purchaseData.groupby(["Gender"]).count()["Price"]
purchaseCount = purchaseData.groupby(["Gender"]).count()["Price"]
avgPrice = purchaseData.groupby(["Gender"]).mean()["Price"]
totalPurchase = purchaseData.groupby(["Gender"]).sum()["Price"]
personTotal = totalPurchase / genderCount

genderAnalysis = pd.DataFrame({"PurchaseCount": purchaseCount,
                              "AveragePurchasePrice":avgPrice,
                              "TotalPurchase":totalPurchase,
                              "PerPersonTotal":personTotal})
genderAnalysis
# Out:
#                        PurchaseCount  AveragePurchasePrice  TotalPurchase  \
# Gender
# Female                           113              3.203009         361.94
# Male                             652              3.017853        1967.64
# Other / Non-Disclosed             15              3.346000          50.19
#
#                        PerPersonTotal
# Gender
# Female                       3.203009
# Male                         3.017853
# Other / Non-Disclosed        3.346000

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
bins = [0, 18, 19, 22, 25, 45]
ageBins = ["0-18", "19-22", "23-25", "25-45", "45+"]

purchaseData["Age Group"] = pd.cut(purchaseData["Age"], bins, labels=ageBins, include_lowest=True)
purchaseData.head()

ageCount = purchaseData.groupby(["Age Group"]).count()["Price"]
ageTotal = ageCount / purchaseData["SN"].value_counts().count()

ageAnalysis = pd.DataFrame({"TotalCount": ageCount,
                            "PercentofTotal":ageTotal})
ageAnalysis
# Out:
#            TotalCount  PercentofTotal
# Age Group
# 0-18              164        0.284722
# 19-22              23        0.039931
# 23-25             231        0.401042
# 25-45             193        0.335069
# 45+               169        0.293403

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
bins = [0, 18, 19, 22, 25, 45]
ageBins = ["0-18", "19-22", "23-25", "25-45", "45+"]

purchaseData["Age Group"] = pd.cut(purchaseData["Age"], bins, labels=ageBins, include_lowest=True)
purchaseData.head()

ageCount = purchaseData.groupby(["Age Group"]).count()["Price"]
agePurchaseCount = purchaseData.groupby(["Age Group"]).count()["Price"]
ageAvgPrice = purchaseData.groupby(["Age Group"]).mean()["Price"]
ageTotalPurchase = purchaseData.groupby(["Age Group"]).sum()["Price"]
ageTotal = ageTotalPurchase / ageCount

ageAnalysis = pd.DataFrame({"PurchaseCount": ageCount,
                              "AveragePurchasePrice":ageAvgPrice,
                              "TotalPurchase":ageTotalPurchase,
                              "AgeGroupTotal":ageTotal})
ageAnalysis
# Out:
#            PurchaseCount  AveragePurchasePrice  TotalPurchase  AgeGroupTotal
# Age Group
# 0-18                 164              3.065976         502.82       3.065976
# 19-22                 23              3.042609          69.98       3.042609
# 23-25                231              3.038571         701.91       3.038571
# 25-45                193              3.077979         594.05       3.077979
# 45+                  169              3.023728         511.01       3.023728

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
playerPurchaseCount = purchaseData.groupby(["SN"]).count()["Price"]
playerAvgPrice = purchaseData.groupby(["SN"]).mean()["Price"]
playerPurchase = purchaseData.groupby(["SN"]).sum()["Price"]

topSpenders = pd.DataFrame({"PurchaseCount": playerPurchaseCount,
                            "AveragePurchasePrice":playerAvgPrice,
                            "TotalPurchaseValue":playerPurchase})
topSpenders.sort_values(["TotalPurchaseValue"], ascending = False)
# Out:
#              PurchaseCount  AveragePurchasePrice  TotalPurchaseValue
# SN
# Lisosia93                5              3.792000               18.96
# Idastidru52              4              3.862500               15.45
# Chamjask73               3              4.610000               13.83
# Iral74                   4              3.405000               13.62
# Iskadarya95              3              4.366667               13.10
# ...                    ...                   ...                 ...
# Ililsasya43              1              1.020000                1.02
# Irilis75                 1              1.020000                1.02
# Aidai61                  1              1.010000                1.01
# Chanirra79               1              1.010000                1.01
# Alo38                    1              1.000000                1.00
#
# [576 rows x 3 columns]

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
itemPurchaseCount = purchaseData.groupby(["Item ID", "Item Name"]).count()["Price"]
itemAvgPrice = purchaseData.groupby(["Item ID", "Item Name"]).mean()["Price"]
itemPurchase = purchaseData.groupby(["Item ID", "Item Name"]).sum()["Price"]

topItems = pd.DataFrame({"PurchaseCount":itemPurchaseCount,
                         "AveragePurchasePrice":itemAvgPrice,
                         "TotalPurchaseValue":itemPurchase})
topItems.sort_values(["TotalPurchaseValue"], ascending = False)
# Out:
#                                                       PurchaseCount  \
# Item ID Item Name
# 92      Final Critic                                             13
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 82      Nirvana                                                   9
# 145     Fiery Glass Crusader                                      9
# 103     Singed Scalpel                                            8
# ...                                                             ...
# 28      Flux, Destroyer of Due Diligence                          2
# 125     Whistling Mithril Warblade                                2
# 126     Exiled Mithril Longsword                                  1
# 104     Gladiator's Glaive                                        1
# 42      The Decapitator                                           1
#
#                                                       AveragePurchasePrice  \
# Item ID Item Name
# ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
itemPurchaseCount = purchaseData.groupby(["Item ID", "Item Name"]).count()["Price"]
itemAvgPrice = purchaseData.groupby(["Item ID", "Item Name"]).mean()["Price"]
itemPurchase = purchaseData.groupby(["Item ID", "Item Name"]).sum()["Price"]

topItems = pd.DataFrame({"PurchaseCount":itemPurchaseCount,
                         "AveragePurchasePrice":itemAvgPrice,
                         "TotalPurchaseValue":itemPurchase})
topItems.sort_values(["TotalPurchaseValue"], ascending = False)
# Out:
#                                                       PurchaseCount  \
# Item ID Item Name
# 92      Final Critic                                             13
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 82      Nirvana                                                   9
# 145     Fiery Glass Crusader                                      9
# 103     Singed Scalpel                                            8
# ...                                                             ...
# 28      Flux, Destroyer of Due Diligence                          2
# 125     Whistling Mithril Warblade                                2
# 126     Exiled Mithril Longsword                                  1
# 104     Gladiator's Glaive                                        1
# 42      The Decapitator                                           1
#
#                                                       AveragePurchasePrice  \
# Item ID Item Name
# ...
