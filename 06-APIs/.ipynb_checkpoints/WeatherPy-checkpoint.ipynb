# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
pip install citipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import subprocess
import sys
import seaborn as sn
import statsmodels.api as sm

def install(package):
    subprocess.check_call([sys.executable, "-m", "pip", "install", package])
    
# Import API key
from api_keys import weather_api_key

def install(package):
    subprocess.check_call([sys.executable, "-m", "pip", "install", package])

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 622

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
firstCity = cities[0]

units = "imperial"
url = f"http://api.openweathermap.org/data/2.5/weather?q={firstCity}&appid={weather_api_key}&units={units}"
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?q=vardo&appid=9328c78d7ff080a97adada80bcf92b52&units=imperial'

# %%
lats = []
longs = []
temps = []
humids = []
pressures = []
winds = []
clouds = []

citiesFound = []
counter = 0

# %%
for city in cities:
    units = "imperial"
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units={units}"
    try:
        response = requests.get(url).json()
        code = response["cod"]
        if code == 200:  
            citiesFound.append(city)
            lats.append(response["coord"]["lat"])
            longs.append(response["coord"]["lon"])
            temps.append(response["main"]["temp"])
            humids.append(response["main"]["humidity"])
            pressures.append(response["main"]["pressure"])
            winds.append(response["wind"]["speed"])
            clouds.append(response["clouds"]["all"])
        if counter % 50 == 0:
            print(counter)
    except Exception as e:
        print(e)
    counter += 1
    time.sleep(1)
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600

# %%
counter
# Out:
# 622

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df = pd.DataFrame()
df["cities"] = citiesFound
df["latitude"] = lats
df["longitude"] = longs
df["temperature"] = temps
df["humidity"] = humids
df["pressure"] = pressures
df["wind_speed"] = winds
df["cloudiness"] = clouds
df.head()
# Out:
#          cities  latitude  longitude  temperature  humidity  pressure  \
# 0         vardo     70.37      31.11        37.53        80      1013
# 1  puerto ayora     -0.74     -90.35        83.52        62      1012
# 2     busselton    -33.65     115.33        54.64        38      1007
# 3     ostrovnoy     68.05      39.51        26.96        93      1018
# 4      khatanga     71.97     102.50        14.29        97      1014
#
#    wind_speed  cloudiness
# 0       13.18           7
# 1        3.36          20
# 2       10.40           2
# 3       13.02           2
# 4        0.78         100

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
mask = df["humidity"]>100
dfSub = df.loc[mask].reset_index(drop = True)
dfSub.head()
#  No cities with humidity over 100%
# Out:
# Empty DataFrame
# Columns: [cities, latitude, longitude, temperature, humidity, pressure, wind_speed, cloudiness]
# Index: []

# %%
# Extract relevant fields from the data frame

# Export the City_Data into a csv
df.to_csv(r'CityWeather.csv', index = False)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
df.describe()
# Out:
#          latitude   longitude  temperature    humidity     pressure  \
# count  568.000000  568.000000   568.000000  568.000000   568.000000
# mean    19.816426   19.105229    61.977958   67.230634  1011.695423
# std     34.150726   91.822203    19.391829   22.867797    13.128742
# min    -54.800000 -179.170000     4.770000    8.000000   737.000000
# 25%     -8.907500  -61.695000    49.237500   51.750000  1008.000000
# 50%     23.405000   23.060000    64.400000   74.000000  1013.000000
# 75%     49.827500  102.517500    77.852500   86.000000  1016.250000
# max     78.220000  178.420000   101.280000  100.000000  1026.000000
#
#        wind_speed  cloudiness
# count  568.000000  568.000000
# mean     7.854877   52.637324
# std      5.155970   39.999984
# min      0.160000    0.000000
# 25%      3.940000    6.750000
# 50%      6.780000   63.000000
# 75%     10.290000   90.250000
# max     29.970000  100.000000

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
df.plot(kind='scatter',x='latitude',y='temperature',color='red')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
df.plot(kind='scatter',x='latitude',y='humidity',color='brown')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
df.plot(kind='scatter',x='latitude',y='cloudiness',color='orange')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
df.plot(kind='scatter',x='latitude',y='wind_speed',color='blue')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
corrs = df.corr()
corrs

sn.heatmap(corrs)

# %%
x = df["cloudiness"]
y = df["humidity"]

x = sm.add_constant(x)

model = sm.OLS(y, x).fit()
predictions = model.predict(x)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               humidity   R-squared:                       0.093
# Model:                            OLS   Adj. R-squared:                  0.092
# Method:                 Least Squares   F-statistic:                     58.18
# Date:                Sat, 02 May 2020   Prob (F-statistic):           1.02e-13
# Time:                        16:02:04   Log-Likelihood:                -2555.4
# No. Observations:                 568   AIC:                             5115.
# Df Residuals:                     566   BIC:                             5123.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         58.0432      1.512     38.380      0.000      55.073      61.014
# ...

# %%
# Create Northern and Southern Hemisphere DataFrames
mask = df["latitude"]>0
dfNorthern = df.loc[mask].reset_index(drop = True)

mask = df["latitude"]<0
dfSouthern = df.loc[mask].reset_index(drop = True)

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = dfNorthern['latitude']
y_values = dfNorthern['temperature']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,20),fontsize=15,color="red")
plt.title("Northern Hemisphere - Temperature vs. Latitude")
plt.xlabel('Latitude')
plt.ylabel('Temperature')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7819736262340203

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = dfSouthern['latitude']
y_values = dfSouthern['temperature']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,90),fontsize=15,color="red")
plt.title("Southern Hemisphere - Temperature vs. Latitude")
plt.xlabel('Latitude')
plt.ylabel('Temperature')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.546166652161891

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = dfNorthern['latitude']
y_values = dfNorthern['humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,15),fontsize=15,color="red")
plt.title("Northern Hemisphere - Humidity vs. Latitude")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.03442079832504333

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = dfSouthern['latitude']
y_values = dfSouthern['humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,18),fontsize=15,color="red")
plt.title("Southern Hemisphere - Humidity vs. Latitude")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.016483973656954982

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = dfNorthern['latitude']
y_values = dfNorthern['cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,30),fontsize=15,color="red")
plt.title("Northern Hemisphere - Cloudiness vs. Latitude")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.00691197509286856

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = dfSouthern['latitude']
y_values = dfSouthern['cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,50),fontsize=15,color="red")
plt.title("Southern Hemisphere - Cloudiness vs. Latitude")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.017547235282811973

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = dfNorthern['latitude']
y_values = dfNorthern['wind_speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,27),fontsize=15,color="red")
plt.title("Northern Hemisphere - Wind Speed vs. Latitude")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0015382260680741565

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = dfSouthern['latitude']
y_values = dfSouthern['wind_speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,20),fontsize=15,color="red")
plt.title("Southern Hemisphere - Wind Speed vs. Latitude")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.04293117126509129
